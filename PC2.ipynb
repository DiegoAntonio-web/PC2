# %% [markdown]
# <center><img src="https://i.imgur.com/zRrFdsf.png" width="700"></center>
#
# # Data Formatting (categorical)
#
#
# In this formatting tutorial we will see the categorical case.
#
#
# Let's get some data:

# %%
#Importacion de pandas
import pandas as pd

data = pd.read_excel('https://github.com/DiegoAntonio-web/PC2/blob/main/HDI%20(1).xlsx?raw=true')
data
# Out:
#          Back Table 1. Human Development Index and its components   \
# 0         NaN                                                NaN
# 1         NaN                                                NaN
# 2         NaN                                                NaN
# 3         NaN                                                NaN
# 4    HDI rank                                            Country
# ..        ...                                                ...
# 271       NaN                          Column 2: UNDESA (2022a).
# 272       NaN  Column 3: CEDLAS and World Bank (2022), ICF Ma...
# 273       NaN  Column 4: Barro and Lee (2018), ICF Macro Demo...
# 274       NaN  Column 5: IMF (2022), UNDESA (2022b), United N...
# 275       NaN  Column 6: Calculated based on data in columns ...
#
#                          Unnamed: 2  Unnamed: 3                Unnamed: 4  \
# 0                               NaN         NaN                       NaN
# ...

# %%
#Eliminacion de las 3 primeras filas, ya que no hay data que sirva
data_limpia = data.iloc[3:]
data_limpia
# Out:
#          Back Table 1. Human Development Index and its components   \
# 3         NaN                                                NaN
# 4    HDI rank                                            Country
# 5         NaN                                                NaN
# 6         NaN                        VERY HIGH HUMAN DEVELOPMENT
# 7           1                                        Switzerland
# ..        ...                                                ...
# 271       NaN                          Column 2: UNDESA (2022a).
# 272       NaN  Column 3: CEDLAS and World Bank (2022), ICF Ma...
# 273       NaN  Column 4: Barro and Lee (2018), ICF Macro Demo...
# 274       NaN  Column 5: IMF (2022), UNDESA (2022b), United N...
# 275       NaN  Column 6: Calculated based on data in columns ...
#
#                          Unnamed: 2  Unnamed: 3                Unnamed: 4  \
# 3    Human Development Index (HDI)          NaN  Life expectancy at birth
# ...

# %%
# Eliminacion de columnas que tienen nombres NaN en su primera fila, excepto las 2 primeras
cols_to_keep = data_limpia.columns[:2] #Conservacion de las 2 primeras columnas
data_final = pd.concat([data_limpia[cols_to_keep], data_limpia.loc[:, data_limpia.iloc[0].notna()].iloc[:, 2:]], axis=1)

data_final
# Out:
#          Back Table 1. Human Development Index and its components   \
# 3         NaN                                                NaN
# 4    HDI rank                                            Country
# 5         NaN                                                NaN
# 6         NaN                        VERY HIGH HUMAN DEVELOPMENT
# 7           1                                        Switzerland
# ..        ...                                                ...
# 271       NaN                          Column 2: UNDESA (2022a).
# 272       NaN  Column 3: CEDLAS and World Bank (2022), ICF Ma...
# 273       NaN  Column 4: Barro and Lee (2018), ICF Macro Demo...
# 274       NaN  Column 5: IMF (2022), UNDESA (2022b), United N...
# 275       NaN  Column 6: Calculated based on data in columns ...
#
#                       Unnamed: 6               Unnamed: 8  \
# 3    Expected years of schooling  Mean years of schooling
# 4                        (years)                  (years)
# ...

# %%
#Eliminacion de todas las filas que contengan valores NaN a excepcion de la segunda columna
data_depurada = data_final[~(data_final.iloc[:, 2:].isna().all(axis=1) & data_final.iloc[:, 1].notna())]

data_depurada
# Out:
#          Back Table 1. Human Development Index and its components   \
# 3         NaN                                                NaN
# 4    HDI rank                                            Country
# 5         NaN                                                NaN
# 7           1                                        Switzerland
# 8           2                                             Norway
# ..        ...                                                ...
# 228       NaN                                              World
# 229       NaN                                                NaN
# 258       NaN                                                NaN
# 259       NaN                                                NaN
# 268       NaN                                                NaN
#
#                       Unnamed: 6               Unnamed: 8  \
# 3    Expected years of schooling  Mean years of schooling
# 4                        (years)                  (years)
# ...

# %%
#Eliminacion de filas que contengan solo valores NaN

data_depurada = data_depurada.dropna(how='all')
data_depurada
# Out:
#          Back Table 1. Human Development Index and its components   \
# 3         NaN                                                NaN
# 4    HDI rank                                            Country
# 5         NaN                                                NaN
# 7           1                                        Switzerland
# 8           2                                             Norway
# ..        ...                                                ...
# 221       NaN                                 Sub-Saharan Africa
# 223       NaN                          Least developed countries
# 224       NaN                     Small island developing states
# 226       NaN  Organisation for Economic Co-operation and Dev...
# 228       NaN                                              World
#
#                       Unnamed: 6               Unnamed: 8  \
# 3    Expected years of schooling  Mean years of schooling
# 4                        (years)                  (years)
# ...

# %%
#Reemplzamos celdas que tengan valores NaN como espacios en blanco
data_depurada = data_depurada.fillna('')

data_depurada
# Out:
#          Back Table 1. Human Development Index and its components   \
# 3
# 4    HDI rank                                            Country
# 5
# 7           1                                        Switzerland
# 8           2                                             Norway
# ..        ...                                                ...
# 221                                           Sub-Saharan Africa
# 223                                    Least developed countries
# 224                               Small island developing states
# 226            Organisation for Economic Co-operation and Dev...
# 228                                                        World
#
#                       Unnamed: 6               Unnamed: 8  \
# 3    Expected years of schooling  Mean years of schooling
# 4                        (years)                  (years)
# 5                           2021                     2021
# 7                      16.500299                 13.85966
# ...

# %%
#Reemplzamos celdas que tengan caracteres ".." y "—" como espacios en blanco
data_depurada_final = data_depurada.replace({'..': '', '—': ''})
data_depurada_final
# Out:
#          Back Table 1. Human Development Index and its components   \
# 3
# 4    HDI rank                                            Country
# 5
# 7           1                                        Switzerland
# 8           2                                             Norway
# ..        ...                                                ...
# 221                                           Sub-Saharan Africa
# 223                                    Least developed countries
# 224                               Small island developing states
# 226            Organisation for Economic Co-operation and Dev...
# 228                                                        World
#
#                       Unnamed: 6               Unnamed: 8  \
# 3    Expected years of schooling  Mean years of schooling
# 4                        (years)                  (years)
# 5                           2021                     2021
# 7                      16.500299                 13.85966
# ...
